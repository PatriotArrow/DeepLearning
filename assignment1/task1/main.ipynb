# %%
import numpy as np
import pandas as pd

# %%
def sigmoid(t):
    return 1/(1 + np.exp(-t))

# %%
file_name = r""../datasets/cs1.csv""
df = pd.read_csv(file_name)
# Out:
#   Cell In[1], line 1
#     file_name = r""../datasets/cs1.csv""
#                     ^
# SyntaxError: invalid syntax

# %%
loss()
{
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 loss()
#       2 {
#       3 }
#
# NameError: name 'loss' is not defined
